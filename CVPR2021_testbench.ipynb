# %% [markdown]
# # Data preparation (Do not run!)

# %%
# !git clone https://github.com/thu-ml/ares.git ares

# %%
# !python3 ares/dataset/cifar10.py
# Out:
# 2021-03-20 03:14:41.588125: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 81.9kB [00:02, 37.4kB/s]

# %%
# cd ..
# Out:
# /content/drive/MyDrive/CVPR2021/ares

# %%
# !python3 ares/dataset/imagenet.py

# %%
# !git submodule init

# %%
# !git submodule update --depth 1
# Out:
# remote: Total 0 (delta 0), reused 0 (delta 0), pack-reused 0
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 5), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (7/7), done.
# From https://github.com/locuslab/convex_adversarial
#  * branch            b3f532865cc02aeb6c020b449c2b1f0c13c7f236 -> FETCH_HEAD
# Submodule path 'third_party/convex_adversarial_pytorch': checked out 'b3f532865cc02aeb6c020b449c2b1f0c13c7f236'
# remote: Total 0 (delta 0), reused 0 (delta 0), pack-reused 0
# remote: Enumerating objects: 2580, done.
# remote: Counting objects: 100% (2580/2580), done.
# remote: Compressing objects: 100% (1744/1744), done.
# remote: Total 1962 (delta 788), reused 860 (delta 193), pack-reused 0
# Receiving objects: 100% (1962/1962), 100.35 MiB | 15.49 MiB/s, done.
# Resolving deltas: 100% (788/788), completed with 501 local objects.
# ...

# %%
# !python3 example/imagenet/fast_at.py
# Out:
# Please download "https://drive.google.com/file/d/1UrNEtLWs-fjlM2GPb1JpBGtpffDuHH_4/view" to "/content/drive/MyDrive/CVPR2021/ares/model/imagenet/imagenet_model_weights_4px.pth".

# %%
# my_file = open("/content/drive/MyDrive/CVPR2021/ares/model/imagenet/target.txt", "w")

# my_file.write("First Line\n")
# my_file.write("Second Line")
# my_file = open("/content/drive/MyDrive/CVPR2021/ares/model/imagenet/target.txt")

# content = my_file.read()

# my_file.close()

# print(content)

# %%
# from os import listdir
# from os.path import isfile,join

# img_path = '/content/drive/MyDrive/CVPR2021/ares/model/imagenet/ILSVRC2012_img_val'
# fn = [fn for fn in listdir(img_path)]
# fn.sort()
# len(fn)
# Out:
# 17233

# %%
# my_file = open("/content/drive/MyDrive/CVPR2021/ares/model/imagenet/val.txt")

# string_list_val = my_file.readlines()

# my_file.close()

# string_list[1] = "Edit the list of strings as desired\n"

# my_file = open("/content/drive/MyDrive/CVPR2021/ares/model/imagenet/target1.txt", "w")
# new_file_contents = "".join(string_list)

# my_file.write(new_file_contents)
# my_file.close()

# readable_file = open("/content/drive/MyDrive/CVPR2021/ares/model/imagenet/target1.txt")
# read_file = readable_file.read()
# print(read_file)

# %%
# new_string_val = []
# for i in range(len(string_list_val)):
#   for j in range(len(fn)):
#     if fn[j][0:23]==string_list_val[i][0:23]:
#       sign = 1
#       break
#     elif j>i:
#       sign = 0
#       break
#     else:
#       sign = 0
#   if sign==1:
#     new_string_val.append(string_list_val[i])

# print(len(new_string_val))
# Out:
# 17233

# %%
# my_file = open("/content/drive/MyDrive/CVPR2021/ares/model/imagenet/val_0.txt", "w")
# new_file_contents = "".join(new_string_val)

# my_file.write(new_file_contents)
# my_file.close()

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
import torch

print(torch.cuda.is_available())


print(torch.cuda.current_device())


print(torch.cuda.device(0))


print(torch.cuda.device_count())


print(torch.cuda.get_device_name(0))
# Out:
# True
# 0
# ...
# 1
# Tesla V100-SXM2-16GB

# %%
# !git clone https://github.com/Harry24k/adversairal-attacks-pytorch
# Out:
# Cloning into 'adversairal-attacks-pytorch'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 1142 (delta 85), reused 82 (delta 38), pack-reused 996
# Receiving objects: 100% (1142/1142), 39.59 MiB | 15.93 MiB/s, done.
# Resolving deltas: 100% (667/667), done.

# %%
# !git clone https://github.com/fra31/auto-attack.git
# Out:
# Cloning into 'auto-attack'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 464 (delta 61), reused 29 (delta 14), pack-reused 365
# Receiving objects: 100% (464/464), 40.60 MiB | 18.99 MiB/s, done.
# Resolving deltas: 100% (272/272), done.

# %% [markdown]
# # Initialize the experiments environment

# %%
# mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/CVPR2021
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/CVPR2021'
# /content/drive/MyDrive/CVPR2021/ares/contest

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.2

# %%
# tf.enable_eager_execution()

# %%
cd ares
# Out:
# /content/drive/MyDrive/CVPR2021/ares

# %%
pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/CVPR2021/ares
# ...
#   Running setup.py develop for ares
# ...

# %%
import os
from ares import utils
os.environ["ARES_RES_DIR"] = '/content/drive/MyDrive/CVPR2021/ares/model'
A = utils.get_res_path('1')
print(A)
# !python3 example/cifar10/robust_overfitting.py
# Out:
# /content/drive/MyDrive/CVPR2021/ares/model/1

# %%
cd contest
# Out:
# /content/drive/MyDrive/CVPR2021/ares/contest

# %%
from adversarialA import torchattacks
# atk = torchattacks.PGD(model, eps=8/255, alpha=2/255, steps=4)
# adversarial_images = atk(images, labels)

# %%
ls
# Out:
# attacker/         numpy_attacker/      run_attacks_loader.py  run.py
# check/            numpy_attacker_mim/  run_attacks.py         tmp/
# download_data.sh  numpy_attackerSS/    run_attacksSS.py       tmpSS/
# __init__.py       numpy_attackerZT/    run_attacksZT.py       tmpZT/
# loader.py         README.md            run_checker.py

# %%
from datetime import datetime
tic = datetime.now()
# !python3 run_attacks.py --attacks numpy_attacker_autoattack --output /content/drive/MyDrive/CVPR2021/ares/contest/tmp
toc = datetime.now()
print('Elapsed time: %f seconds' % (toc-tic).total_seconds())
# Out:
# Models:  ['cifar10-pgd_at']
# Attacks:  ['numpy_attacker_autoattack']
# Output Directory:  /content/drive/MyDrive/CVPR2021/ares/contest/tmp
# Using TensorFlow backend.
# WARNING:tensorflow:From run_attacks_loader.py:13: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From run_attacks_loader.py:15: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-04-01 01:55:20.348671: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2021-04-01 01:55:20.348871: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5628ee1e0a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-04-01 01:55:20.348902: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# ...

# %%
 import argparse
import os
import numpy as np
import tensorflow as tf
import sys
sys.path.append("/content/drive/MyDrive/CVPR2021/ares")
from ares.dataset import cifar10, imagenet, dataset_to_iterator
from ares.model import load_model_from_path

MODEL_PATH = os.path.join(os.path.dirname(os.path.abspath(os.path.dirname('/content/drive/MyDrive/CVPR2021/ares/contest/run_attacks.py'))), "example")
MODELS = [
    "cifar10-pgd_at",
    # "cifar10-wideresnet_trades",
    # "cifar10-feature_scatter",
    # "cifar10-robust_overfitting",
    # "cifar10-rst",
    # "cifar10-fast_at",
    # "cifar10-at_he",
    # "cifar10-pre_training",
    # "cifar10-mmc",
    # "cifar10-free_at",
    # "cifar10-awp",
    # "cifar10-hydra",
    # "cifar10-label_smoothing",
    # "imagenet-fast_at",
    # "imagenet-free_at",
]
attack_names = 'numpy_attacker'
BATCH_SIZE = 50

models = ",".join(MODELS)

attacks = ",".join(attack_names)

attack_names = [x for x in attacks.split(",") if len(x) > 0]
model_names = [x for x in models.split(",") if len(x) > 0]
# output_directory = os.path.abspath(output)
# print("Models: ", model_names)
# print("Attacks: ", attack_names)
# print("Output Directory: ", output_directory)

def main(args):
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    session = tf.Session(config=config)

    attack_names = [x for x in args.attacks.split(",") if len(x) > 0]
    model_name = args.model
    output_directory = os.path.abspath(args.output)
    attackers = []
    for attack_name in attack_names:
        attackers.append((attack_name, __import__(attack_name).Attacker))
    run_one_model(model_name, attackers, session, output_directory)

def run_one_model(model_name, attackers, session):
    is_imagenet = model_name.startswith("imagenet-")
    is_cifar10 = model_name.startswith("cifar10-")
    if is_imagenet:
        dataset_name = "imagenet"
        eps = 4.0 / 255.0
        model_path = os.path.join("imagenet", model_name[len("imagenet-"):] + ".py")
    elif is_cifar10:
        dataset_name = "cifar10"
        eps = 8.0 / 255.0
        model_path = os.path.join("cifar10", model_name[len("cifar10-"):] + ".py")
    else:
        raise AssertionError("Invalid model {}!".format(model_name))
    model_path = os.path.join(MODEL_PATH, model_path)

    model = load_model_from_path(model_path).load(session)
    if is_imagenet:
        dataset = imagenet.load_dataset_for_classifier(model, offset=0, load_target=False).take(1000)
    else:
        dataset = cifar10.load_dataset_for_classifier(model, offset=0, load_target=False).take(1000)
    xs_ph = tf.placeholder(model.x_dtype, shape=(None, *model.x_shape))
    labels_op = model.labels(xs_ph)
    # ys_ph = tf.placeholder(model.y_dtype)
    # logits, labels = model.logits_and_labels(xs_ph)
    # all_logits_list = []
    # all_label_list = []
    for attack_name, attacker_class in attackers:
        print("Running {} on {}".format(attack_name, model_name))
        attacker = attacker_class(model, BATCH_SIZE, dataset_name, session)
        attacker.config(magnitude=eps * (model.x_max - model.x_min))
        success_count = 0
        for batch, (_, xs, ys) in enumerate(dataset_to_iterator(dataset.batch(BATCH_SIZE), session)):
            xs_adv,loss = attacker.batch_attack(xs.copy(), ys=ys.copy())
            xs_adv = xs_adv.astype(np.float32)
            # all_logits_list.append(logits_list)
            # all_label_list.append(label_list)
            xs_adv = np.clip(xs_adv, xs - eps * (model.x_max - model.x_min), xs + eps * (model.x_max - model.x_min))
            xs_adv = np.clip(xs_adv, model.x_min, model.x_max)
            assert not np.any(np.isnan(xs_adv))
            labels = session.run(labels_op, feed_dict={xs_ph: xs_adv})
            # logits,_ = session.run((logits, labels), feed_dict={xs_ph: xs, ys_ph: ys})
            success_count += np.sum(np.logical_not(np.equal(labels, ys)))
            # logits_list.append(logits)
        score = success_count / 1000.0
        print("Score for {} on {}: {}".format(attack_name, model_name, score))
        # with open(os.path.join(output_directory, "{}.csv".format(attack_name)), "a") as f:
        #     f.write("{},{}\n".format(model_name, score))
        #     f.flush()
    return loss
# Out:
# Using TensorFlow backend.

# %%
attacks = "numpy_attacker"
attack_names = [x for x in attacks.split(",") if len(x) > 0]

# %%
attack_names
# Out:
# ['numpy_attacker']

# %%
attackers = []
for attack_name in attack_names:
    attackers.append((attack_name, __import__(attack_name).Attacker))

# %%
attackers
# Out:
# [('numpy_attacker', numpy_attacker.Attacker)]

# %%
for attack_name, attacker_class in attackers:
  print(attack_name,attacker_class)
# Out:
# numpy_attacker <class 'numpy_attacker.Attacker'>

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# %%
loss = run_one_model("cifar10-pgd_at", attackers, session,)
# Out:
# WARNING:tensorflow:Entity <function load_dataset.<locals>.<lambda> at 0x7f9860878e60> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Str'
# WARNING: Entity <function load_dataset.<locals>.<lambda> at 0x7f9860878e60> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Str'
# ...

# %%
loss.shape
# Out:
# (50,)

# %%
np.shape(all_logits)
# Out:
# (20, 3, 50, 10)

# %%
np.shape(all_list)
# Out:
# (20, 3, 50)

# %%
pr = []
if len(pr) is 0:
  print(1)
# Out:
# 1

# %%
import copy

a = [0,1]
b = a.copy()

# %%
a = [1,0]
b
# Out:
# [0, 1]
